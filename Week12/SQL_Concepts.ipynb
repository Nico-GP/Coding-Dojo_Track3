# %% [markdown]
# <a href="https://colab.research.google.com/github/Nico-GP/Coding-Dojo_Track3/blob/main/Week12/SQL_Concepts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **CODING DOJO**: SQL Concepts
# ## Creado por: Nicolas Gonzalez
# ### Descripcion: Conceptos basicos de SQL
# * Creado: 23/03/22
# * Ultima Actualizacion: 23/03/22

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
sd = pd.read_csv('/content/drive/My Drive/CodingDojo/Week12/School_Details.csv')
sd.head()
# Out:
#   DistrictName EstablishmentCode  \
# 0         East             S0169
# 1         East             S0099
# 2         East             S0848
# 3         East             S0190
# 4         East             S0111
#
#                                    EstablishmentName   BRCName  \
# 0               BUDANG GOVERNMENT PRIMARY SCHOOL (E)  Duga Brc
# 1  CENTRAL PENDAM GOVERNMENT SENIOR SECONDARY SCHOOL  Duga Brc
# 2              CENTRAL POINT ACADEMY, CENTRAL PENDAM  Duga Brc
# 3      CHEURIBOTEY GOVERNMENT JUNIOR HIGH SCHOOL (E)  Duga Brc
# 4                   DUGA GOVERNMENT SECONDARY SCHOOL  Duga Brc
#
#                                              CRCName SchoolLevel  \
# 0  Central Pendam Government Senior Secondary School          PS
# 1  Central Pendam Government Senior Secondary School         SSS
# 2  Central Pendam Government Senior Secondary School          SS
# 3  Central Pendam Government Senior Secondary School         JHS
# 4  Central Pendam Government Senior Secondary School          SS
#
#       ManagementName            LocalityHabitation SubdivisionName  \
# 0        State Govt.                        BUDANG         Gangtok
# 1        State Govt.                CENTRAL PENDAM         Gangtok
# 2  Private (Unaided)  UPPER BHURUNG CENTRAL PENDAM         Gangtok
# 3        State Govt.                   CHEURIBOTEY         Gangtok
# 4        State Govt.                          DUGA         Gangtok
#
#   ConstituencyName  ...    EstablishedDate DistrictHQDistance (in Km)  \
# 0          Rhenock  ...              28126                       58.0
# 1      West Pandam  ...              15342                       50.0
# 2      West Pandam  ...  37257.38680555556                       49.0
# 3      West Pandam  ...              28856                       60.0
# 4      West Pandam  ...               1828                       52.0
#
#   CRCDistance (in Km) BACDistance (in Km) IsRecognized           RecognizedBy  \
# 0                 8.0                16.0   Recognized                   HRDD
# 1                 0.0                 6.0   Recognized                   HRDD
# 2                 1.5                 6.0   Recognized  HRDD, GOVT. OF SIKKIM
# 3                 6.0                 6.0   Recognized            State Govt.
# 4                 0.0                 0.5   Recognized               c.b.s.e.
#
#   ContactPersonName LowestClass HighestClass BoardName
# 0               NaN     Class 1      Class 5       NaN
# 1               NaN     Class 1     Class 12  C.B.S.E.
# 2               NaN     Class 1     Class 10  C.B.S.E.
# 3               NaN     Class 1      Class 8       NaN
# 4               NaN     Class 1     Class 10  C.B.S.E.
#
# [5 rows x 30 columns]

# %% [markdown]
# Se crea motor SQL

# %%
engine = create_engine('sqlite:///schools.db', echo = True)
conn = engine.connect()

# %% [markdown]
# Se crea base de datos en formato SQL

# %%
sqlite_table = 'school_details'
sd.to_sql(sqlite_table, conn, if_exists = 'fail')

# %% [markdown]
# # Comandos basicos

# %% [markdown]
# ### Select & From

# %% [markdown]
# Llama las columnas NombreEstablecimiento, NivelEscolar y SitioWeb

# %%
sql = """
SELECT EstablishmentName, SchoolLevel, Website
FROM school_details
"""

sd = pd.read_sql_query(sql, engine)
sd.head()
# Out:
# 2022-03-23 21:45:15,476 INFO sqlalchemy.engine.Engine
# SELECT EstablishmentName, SchoolLevel, Website
# FROM school_details
#
# 2022-03-23 21:45:15,492 INFO sqlalchemy.engine.Engine [raw sql] ()
#                                    EstablishmentName SchoolLevel  \
# 0               BUDANG GOVERNMENT PRIMARY SCHOOL (E)          PS
# 1  CENTRAL PENDAM GOVERNMENT SENIOR SECONDARY SCHOOL         SSS
# 2              CENTRAL POINT ACADEMY, CENTRAL PENDAM          SS
# 3      CHEURIBOTEY GOVERNMENT JUNIOR HIGH SCHOOL (E)         JHS
# 4                   DUGA GOVERNMENT SECONDARY SCHOOL          SS
#
#                                      Website
# 0                                       None
# 1                                       None
# 2  www.facebook.com/khanalkeshav (Group-CPA)
# 3                                       None
# 4                                       None

# %% [markdown]
# ### Where

# %% [markdown]
# Muestra el NombreEstablecimiento y DistanciaDistrito (en km) de colegios en los que DistanciaDistrito (en km) es más de 100 km.0

# %%
sql = """
SELECT EstablishmentName, "DistrictHQDistance (in Km)"
FROM school_details
WHERE "DistrictHQDistance (in Km)" > 100
"""

sd = pd.read_sql_query(sql, engine)
sd.head()
# Out:
# 2022-03-23 21:45:17,792 INFO sqlalchemy.engine.Engine
# SELECT EstablishmentName, "DistrictHQDistance (in Km)"
# FROM school_details
# WHERE "DistrictHQDistance (in Km)" > 100
#
# 2022-03-23 21:45:17,798 INFO sqlalchemy.engine.Engine [raw sql] ()
#                     EstablishmentName  DistrictHQDistance (in Km)
# 0  DODACHEN GOVERNMENT PRIMARY SCHOOL                       150.0
# 1   DEOLING GOVERNMENT PRIMARY SCHOOL                       107.0
# 2       PEMA TSEL ACADEMY(PHADAMCHEN)                       110.0
# 3    ZULUCK GOVERNMENT PRIMARY SCHOOL                       120.0
# 4   BHARENG GOVERNMENT PRIMARY SCHOOL                       150.0

# %% [markdown]
# Muestra NombreEstablecimiento, NivelEscolar, DistanciaDistrito (en km) de colegios donde el nivel escolar es Junior High School

# %%
sql = """
SELECT EstablishmentName, SchoolLevel, "DistrictHQDistance (in Km)"
FROM school_details
WHERE SchoolLevel = 'JHS'
"""

sd = pd.read_sql_query(sql, engine)
sd.head()
# Out:
# 2022-03-23 21:45:18,703 INFO sqlalchemy.engine.Engine
# SELECT EstablishmentName, SchoolLevel, "DistrictHQDistance (in Km)"
# FROM school_details
# WHERE SchoolLevel = 'JHS'
#
# 2022-03-23 21:45:18,715 INFO sqlalchemy.engine.Engine [raw sql] ()
#                                EstablishmentName SchoolLevel  \
# 0  CHEURIBOTEY GOVERNMENT JUNIOR HIGH SCHOOL (E)         JHS
# 1               PADMA KUMARI PUBLIC SCHOOL, DUGA         JHS
# 2           SAJONG GOVERNMENT JUNIOR HIGH SCHOOL         JHS
# 3      SINGLEYBONG GOVERNMENT JUNIOR HIGH SCHOOL         JHS
# 4                          SUNRISE ACADEMY, DUGA         JHS
#
#    DistrictHQDistance (in Km)
# 0                        60.0
# 1                        48.0
# 2                        57.0
# 3                        38.0
# 4                        47.0

# %% [markdown]
# ### Wildcards & Like

# %% [markdown]
# Muestra NombreEstablecimiento, NivelEscolar, DistanciaDistrito (en km) de colegios que contengan las palabras “Junior High” en su nombre

# %%
sql = """
SELECT EstablishmentName, SchoolLevel, "DistrictHQDistance (in Km)"
FROM school_details
WHERE EstablishmentName LIKE '%JUNIOR HIGH%'
"""

sd = pd.read_sql_query(sql, engine)
sd.head()
# Out:
# 2022-03-23 21:45:23,697 INFO sqlalchemy.engine.Engine
# SELECT EstablishmentName, SchoolLevel, "DistrictHQDistance (in Km)"
# FROM school_details
# WHERE EstablishmentName LIKE '%JUNIOR HIGH%'
#
# 2022-03-23 21:45:23,699 INFO sqlalchemy.engine.Engine [raw sql] ()
#                                EstablishmentName SchoolLevel  \
# 0  CHEURIBOTEY GOVERNMENT JUNIOR HIGH SCHOOL (E)         JHS
# 1           SAJONG GOVERNMENT JUNIOR HIGH SCHOOL         JHS
# 2      SINGLEYBONG GOVERNMENT JUNIOR HIGH SCHOOL         JHS
# 3          BORDANG GOVERNMENT JUNIOR HIGH SCHOOL         JHS
# 4     RANGPO BAZAR GOVERNMENT JUNIOR HIGH SCHOOL         JHS
#
#    DistrictHQDistance (in Km)
# 0                        60.0
# 1                        57.0
# 2                        38.0
# 3                        33.0
# 4                        47.0

# %% [markdown]
# ### Limit & Order By

# %% [markdown]
# Muestra NombreEstablecimiento, NivelEscolar, DistanciaDistrito (en km) de colegios cuyo nombre comience con la letra “C”. Ordena los resultados de forma alfabética por nombre de colegio  y limita los resultados de la consulta a 10 líneas

# %%
sql = """
SELECT EstablishmentName, SchoolLevel, "DistrictHQDistance (in Km)"
FROM school_details
WHERE EstablishmentName LIKE 'C%'
ORDER BY EstablishmentName
LIMIT 10
"""

sd = pd.read_sql_query(sql, engine)
sd.head()
# Out:
# 2022-03-23 21:45:24,360 INFO sqlalchemy.engine.Engine
# SELECT EstablishmentName, SchoolLevel, "DistrictHQDistance (in Km)"
# FROM school_details
# WHERE EstablishmentName LIKE 'C%'
# ORDER BY EstablishmentName
# LIMIT 10
#
# 2022-03-23 21:45:24,362 INFO sqlalchemy.engine.Engine [raw sql] ()
#                              EstablishmentName SchoolLevel  \
# 0  C.M.RAI GOVERNMENT SECONDARY SCHOOL (OMCHU)          SS
# 1                      CANAAN SCHOOL, RANIPOOL         JHS
# 2                  CANARY BIRD ACADEMY, KARTOK          PS
# 3          CAROL ACADEMY, YANGSUM UPPER BERFOK         JHS
# 4      CENTRAL MARTAM GOVERNMENT JUNIOR SCHOOL         JHS
#
#    DistrictHQDistance (in Km)
# 0                        26.0
# 1                         0.0
# 2                        38.0
# 3                        50.0
# 4                        50.0

# %% [markdown]
# Muestra los nombres de los colegios de áreas urbanas. Ordena los resultados en orden alfabético inverso

# %%
sql = """
SELECT EstablishmentName, LocatedInRuralOrUrban
FROM school_details
WHERE LocatedInRuralOrUrban LIKE 'Urban%'
ORDER BY EstablishmentName DESC
"""

sd = pd.read_sql_query(sql, engine)
sd.head()
# Out:
# 2022-03-23 21:45:24,979 INFO sqlalchemy.engine.Engine
# SELECT EstablishmentName, LocatedInRuralOrUrban
# FROM school_details
# WHERE LocatedInRuralOrUrban LIKE 'Urban%'
# ORDER BY EstablishmentName DESC
#
# 2022-03-23 21:45:24,981 INFO sqlalchemy.engine.Engine [raw sql] ()
#                        EstablishmentName LocatedInRuralOrUrban
# 0       ZULUCK GOVERNMENT PRIMARY SCHOOL            Urban Area
# 1       ZOOM GOVERNMENT SECONDARY SCHOOL            Urban Area
# 2  ZITLANG GOVERNMENT JUNIOR HIGH SCHOOL            Urban Area
# 3       ZINGLA GOVERNMENT PRIMARY SCHOOL            Urban Area
# 4                   ZENITH PUBLIC SCHOOL            Urban Area

# %% [markdown]
# ### Aliasing

# %% [markdown]
# Repite la consulta anterior, pero renombra la columna que se muestra como “nombre”

# %%
sql = """
SELECT EstablishmentName AS 'Name', LocatedInRuralOrUrban
FROM school_details
WHERE LocatedInRuralOrUrban LIKE 'Urban%'
ORDER BY EstablishmentName DESC
"""

sd = pd.read_sql_query(sql, engine)
sd.head()
# Out:
# 2022-03-23 21:45:27,631 INFO sqlalchemy.engine.Engine
# SELECT EstablishmentName AS 'Name', LocatedInRuralOrUrban
# FROM school_details
# WHERE LocatedInRuralOrUrban LIKE 'Urban%'
# ORDER BY EstablishmentName DESC
#
# 2022-03-23 21:45:27,634 INFO sqlalchemy.engine.Engine [raw sql] ()
#                                     Name LocatedInRuralOrUrban
# 0       ZULUCK GOVERNMENT PRIMARY SCHOOL            Urban Area
# 1       ZOOM GOVERNMENT SECONDARY SCHOOL            Urban Area
# 2  ZITLANG GOVERNMENT JUNIOR HIGH SCHOOL            Urban Area
# 3       ZINGLA GOVERNMENT PRIMARY SCHOOL            Urban Area
# 4                   ZENITH PUBLIC SCHOOL            Urban Area

# %% [markdown]
# Se cierra la conexión con la base de datos

# %%
conn.close()
